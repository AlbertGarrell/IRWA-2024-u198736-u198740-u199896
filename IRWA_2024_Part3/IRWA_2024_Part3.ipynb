# %% [markdown]
# # IMPORTS

# %% [markdown]
# In this section we are importing and installing all necessary libraries:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/Shareddrives/INFO RETREIVAL/PROJECT/Part 3
# Out:
# /content/drive/Shareddrives/INFO RETREIVAL/PROJECT/Part 3

# %%
data_path = './data/'

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# !pip install demoji
# Out:
# Collecting demoji
#   Downloading demoji-1.1.0-py3-none-any.whl.metadata (9.2 kB)
# Downloading demoji-1.1.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: demoji
# Successfully installed demoji-1.1.0

# %%
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.46.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2024.8.30)

# %%
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import pandas as pd
import json
import re
import demoji
import time
from array import array

# %% [markdown]
# Importing 'Build terms' function from previous part: <br>
#
# Note: We will use it to pre-process the input query

# %%
def build_terms(line):
    """
    Description:
    Preprocess the text (tweet) by removing stop words, punctuation (but keeping numbers), URLs,
    stemming, transforming to lowercase, and extracting hashtags. The hashtags are excluded
    from the preprocessed text.

    Input:
    line -- string (text) to be preprocessed

    Output:
    preprocessed_line -- a list of tokens corresponding to the input text after preprocessing
    hashtags -- a list of extracted hashtags
    """

    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))

    # Transform to lowercase
    line = line.lower()

    # HASHTAGS

    # Extract hashtags (keeping the # symbol)
    hashtags = re.findall(r'#\w+', line)
    # Remove punctuation but keep numbers
    hashtags = [re.sub(r'[^a-z0-9\s]', '', word) for word in hashtags]
    # Remove empty strings (in case stemming or other operations result in an empty hashtag)
    hashtags = [word for word in hashtags if word]

    # LINE

    # Remove emojis using demoji
    line = demoji.replace(line, " ")
    # Remove hashtags from the text --> remove all the word
    line = re.sub(r'#\w+', '', line)
    # Remove URLs
    line = re.sub(r'http\S+|www\S+|https\S+', '', line)
    # Remove punctuation but keep numbers (and hashtags are already removed)
    line = re.sub(r'[^a-z0-9\s]', '', line)
    # Tokenize the text to get a list of terms
    line = line.split()
    # Remove the word amp since & it is parsed as &amp and it is one of the most frequent words!
    line = [word for word in line if word != 'amp']
    # Remove stopwords
    line = [word for word in line if word not in stop_words]
    # Perform stemming
    line = [stemmer.stem(word) for word in line]

    # Return preprocessed text and hashtags
    return line, hashtags # return the preprocessed tweet content and hashtags

# %% [markdown]
# # Load the original and processed tweets json files

# %% [markdown]
# If data is not loaded from json files, then it will need to be imported farmer's protest tweets file, create the dictionaries and apply build terms function. With the already created dictionaries (in json files), data is loaded faster!
#
# Note: Data from json files came from the dictionaries created in the first part of the project.

# %% [markdown]
# First let's load processed tweets dictionary:

# %%
with open(data_path + 'processed_tweets.json', 'r') as f:
    processed_tweets_dict = json.load(f)

# %%
print(f"We have {len(processed_tweets_dict)} processed tweets!")
# Out:
# We have 48429 processed tweets!

# %% [markdown]
# Print a sample:

# %%
processed_tweets_dict["doc_37"]
# Out:
# {'tweet': ['remain',
#   'unit',
#   'dont',
#   'fall',
#   'govt',
#   'tactic',
#   'tri',
#   'hard',
#   'creat',
#   'divis',
#   'within',
#   'protest'],
#  'hashtags': ['farmersprotest',
#   'modiignoringfarmersdeaths',
#   'farmersprotests',
#   'modidontsellfarmers']}

# %% [markdown]
# Now let's load the original tweets dictionary:

# %%
with open(data_path + 'original_tweets.json', 'r') as f:
    original_tweets_dict = json.load(f)

# %% [markdown]
# Print same sample as before:

# %%
original_tweets_dict["doc_37"]
# Out:
# {'tweet': "Remain United 👇🏾👇🏾 Dont fall into govt's tactics they are trying hard to create a division within the protests #FarmersProtest #ModiIgnoringFarmersDeaths #FarmersProtests #ModiDontSellFarmers https://t.co/4eX8ckNLJT",
#  'hashtags': ['#FarmersProtest',
#   '#ModiIgnoringFarmersDeaths',
#   '#FarmersProtests',
#   '#ModiDontSellFarmers'],
#  'date': '2021-02-24T08:57:35+00:00',
#  'likes': 1,
#  'retweets': 1,
#  'url': 'https://twitter.com/B56Ricky/status/1364499704147374082',
#  'comment_count': 0}

# %% [markdown]
# # <b>RANKING 1: </b> TF-IDF & COSINE SIMILARITY

# %% [markdown]
# ## Inverted Index

# %% [markdown]
# We are using the same full inverted index as the one used in the previous part:

# %%
def create_index(tweets):
    """
    Description:
    Creates a full inverted index based on the content of the dictionary

    Input:
    tweets -- dictionary with 'tweet' variable that contains the processed tweet content.

    Output:
    full inverted index with all the corpus processed terms, documents where they appear and its corresponding positions
    """
    # init the dictionary
    index = defaultdict(list)

    for tweet_id, tweet_data in tweets.items():
        # get current tweet content (pre-processed)
        terms = tweet_data['tweet']
        # inverted index for current tweet
        current_tweet_index = defaultdict(lambda: [tweet_id, array('I')])  # defaultdict with list of positions
        #  Counts occurrences of each term in the tweet
        term_counts = defaultdict(int)

        # Build term frequency for this tweet and position lists
        for position, term in enumerate(terms):
            current_tweet_index[term][1].append(position)
            term_counts[term] += 1
        # Update index
        for term, (id, positions) in current_tweet_index.items():
            index[term].append([tweet_id, positions])
    return index

# %% [markdown]
# Inverted Index for all tweets.

# %%
index = create_index(processed_tweets_dict)

# %% [markdown]
# Here is the inverted intex for 'rain' word:

# %%
print(index['rain'])
# Out:
# [['doc_555', array('I', [4])], ['doc_4049', array('I', [0])], ['doc_5773', array('I', [10])], ['doc_6354', array('I', [5])], ['doc_10384', array('I', [9])], ['doc_11880', array('I', [4])], ['doc_12218', array('I', [1])], ['doc_14404', array('I', [16])], ['doc_16995', array('I', [15])], ['doc_18469', array('I', [13])], ['doc_24960', array('I', [9])], ['doc_25326', array('I', [3])], ['doc_25871', array('I', [6])], ['doc_26069', array('I', [2])], ['doc_32517', array('I', [7, 25])], ['doc_35314', array('I', [1])], ['doc_38132', array('I', [13])], ['doc_39395', array('I', [1])], ['doc_39695', array('I', [3])], ['doc_39879', array('I', [8])], ['doc_41832', array('I', [8])]]

# %% [markdown]
# ## TF-IDF Implementation

# %%
def create_tfidf(tweets, num_documents):
    """
    Optimized inverted index creation with TF, DF, and IDF calculations.

    Input:
    tweets -- doctionary of preprocessed tweets
    num_documents -- total number of tweets in the corpus

    Output:
    tf - normalized term frequency for each term in each document
    df - number of documents each term appear in
    idf - inverse document frequency of each term
    """

    tf = defaultdict(list)  # term frequencies of terms in documents
    df = defaultdict(int)    # document frequencies of terms in the corpus
    idf = {}

    for tweet_id, tweet_data in tweets.items():
        terms = tweet_data['tweet']
        current_tweet_index = defaultdict(lambda: [tweet_id, array('I')])  # defaultdict with list of positions
        term_counts = defaultdict(int)  # Counts occurrences of each term in the tweet

        # Build term frequency for this tweet and position lists
        for position, term in enumerate(terms):
            current_tweet_index[term][1].append(position)
            term_counts[term] += 1

        # Calculate L2 norm for the tweet (once per document)
        norm = math.sqrt(sum(count ** 2 for count in term_counts.values()))

        # Update index, TF, and DF
        for term, (id, positions) in current_tweet_index.items():
            # Normalized term frequency
            tf_value = term_counts[term] / norm
            tf[term].append(np.round(tf_value, 4))

            # Increment DF count (only once per document per term)
            df[term] += 1
    # Compute IDF for each term
    for term, doc_count in df.items():
        idf[term] = np.round(np.log(num_documents / doc_count), 4)

    return tf, df, idf

# %%
start_time = time.time()
num_documents = len(processed_tweets_dict.keys())
tf, df, idf = create_tfidf(processed_tweets_dict, num_documents)
print("Total time to create the tf - idf - df dictionaries: {} seconds" .format(np.round(time.time() - start_time, 2)))
# Out:
# Total time to create the tf - idf - df dictionaries: 11.42 seconds

# %% [markdown]
# ## Bert Similarity

# %% [markdown]
# Import a BERT model to compute the similarity between queries and hashtags: <br>
#
# Note: This is part of our score implementation.

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')  # multi-language model
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
def get_embeddings(name_list):

    """
    Generates embeddings for a list of names using a pre-trained model.

    Input:
    name_list -- list of names (strings) for which embeddings are to be generated

    Output:
    embedding -- list of embeddings for each name in name_list
    """

    embedding = model.encode(name_list, convert_to_tensor=False)
    #print("Embedding shape: ", embedding.shape)
    return embedding

def bert_similarity(target_name, embedding, name_list, threshold=0.5):

    """
    Computes the cosine similarity between a target name and a list of names
    based on their embeddings. Returns the highest similarity score if it
    exceeds a threshold, otherwise returns 0.

    Input:
    target_name -- string, the name to compare against name_list
    embedding -- list of embeddings for each name in name_list (output of get_embeddings)
    name_list -- list of names (strings) corresponding to the embeddings
    threshold -- float, minimum similarity score to consider as a match (default 0.5)

    Output:
    best_match[1] -- float, the highest similarity score above the threshold
                     or 0 if no scores exceed the threshold
    """

    if pd.isna(target_name): return None

    target_embedding = model.encode(target_name, convert_to_tensor=False)

    # Compute cosine similarity scores
    cosine_scores = util.cos_sim(target_embedding, embedding)

    # Create a dictionary to store university names and their similarity scores
    similarity_scores = {}
    for i, name in enumerate(name_list):
        similarity_scores[name] = cosine_scores[0][i].item()

    # Sort the scores in descending order
    sorted_scores = dict(sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True))

    best_match = list(sorted_scores.items())[0]

    if best_match[1] > threshold:
        return best_match[1]
    else:
        return 0

# %% [markdown]
# Compute the best hashtags scores based on a given query:

# %%
def best_score (list_hashtags, query,threshold=0.5):

    """
    Finds the highest similarity score between a query and a list of hashtags
    using BERT embeddings, returning the score if it exceeds the threshold (0.5).

    Input:
    list_hashtags -- list of hashtags (strings) for which embeddings are to be generated
    query -- string, the query hashtag to compare against list_hashtags
    threshold -- decision point

    Output:
    float -- highest similarity score if it exceeds 0.5, otherwise 0
    """

    embeddings = get_embeddings(list_hashtags)
    return bert_similarity(query, embeddings, list_hashtags, threshold=threshold)

# %% [markdown]
# ## Ranking Functions

# %% [markdown]
# Now let's rank documents as follows:
# - Given a query, we are creating a final weight with weighted sum of the cosine similarity between query and tweet content, and the BERT similarity between the query combinations and tweet hashtags. That is, if we have two same tweets but the first one has a hashtag relevant to the query and the other one no, then we are giving more score to the second tweet for the ranking.
#
# Note 1: We are creating unions of two words of the query so that we're creating different hashtags from our input query. That is, if the input is "Support farmers of India", we are computing the similarity of hashtags vs "supportfarmer", "supportindia" & "farmerindia" (note that preprocessed query is "support farmer india"). <br>
#
# Note 2: If flag = False, the score is computed as TF-IDF + cosine similarity. For flag = True, the bert similarity is added for an additional weight based on the hashtags similarity with the given query.

# %%
def rank_documents(query, docs, index,processed_tweets, tf, idf, alpha=1, beta=3, flag=False):
    """
    Ranks documents based on their relevance (in descending order) to the query using TF-IDF scores.

    Input:
        query: The search query as a list of terms (preprocessed)
        docs: A list of document IDs to be ranked.
        index: The inverted index for tweets.
        processed_tweets: processed tweets dictionary
        tf: term frequency dictionary
        idf: The inverse document frequency dictionary.
        alpha: Weight for the TF-IDF score.
        beta: Weight for the similarity score between hashtags.
        flag: boolean which indicates whether to use or not the hashtag similarity score (additional to the tf-idf)

    Output:
        A list of document IDs sorted by their relevance to the query and their scores
    """
    doc_vectors = defaultdict(lambda: [0] * len(query))  # Initialize all scores to 0
    query_vector = [0] * len(query)

    query_terms_count = collections.Counter(query)

    query_norm = la.norm(list(query_terms_count.values()))


    for termIndex, term in enumerate(query):
        if term not in index:
        # as the term does not exist, return anything
            return []

        query_vector[termIndex] = query_terms_count[term] / query_norm * idf[term]

        for doc_index, (doc, postings) in enumerate(index[term]):
            if doc in docs:
            #if doc in tf and term in tf[doc] and doc in tfidf and term in tfidf[doc]:
                doc_vectors[doc][termIndex] = tf[term][doc_index] * idf[term]

    # array d'arrays
    scores = [[np.dot(curDocVec, query_vector), doc] for doc, curDocVec in doc_vectors.items() ]

    if flag:
        # compute the similarity between query and hashtags --> we are joining query together as hashtags are one-word terms
        for doc_id in docs:
            # perform combinations of 2 words
            score_tweet = 0
            for i in range(len(query)):
                for j in range(i+1,len(query)):
                    temp = best_score(processed_tweets_dict[doc_id]['hashtags'], query[i]+query[j])
                    score_tweet = max(score_tweet,temp)

            for i in range(len(scores)):
                if scores[i][1] == doc_id:
                    scores[i][0] = (alpha * scores[i][0] + beta * score_tweet)
                    break  # Exit the loop once the doc_id is found

    scores.sort(reverse=True)
    ranked_tweets = [x[1] for x in scores]

    # Sort documents by relevance score (descending)
    return ranked_tweets, scores

def search_tf_idf(query, index, tf, idf, processed_tweets,flag=False):
    """
    Searches for documents relevant to the query using TF-IDF scores.

    Input:
        query: The search query as a string.
        index: The inverted index.
        tf: term frequency term - document
        idf: The inverse document frequency dictionary per term
        processed_tweets: processed tweets dictionary
        flag: boolean which indicates whether to use or not the hashtag similarity score (additional to the tf-idf)

    Output:
        A list of document IDs sorted by their relevance to the query.
    """
    query_terms = build_terms(query)[0]  # Preprocess the query

    docs = set(processed_tweets.keys())
    for term in query_terms:
        try:
            # store in term_docs the ids of the docs that contain "term"
            term_docs=[posting[0] for posting in index[term]]

            # docs = docs Intersection term_docs --> applying AND method for tweets seach
            docs = docs.intersection(set(term_docs))
        except:
            #term is not in index
            pass
    docs = list(docs)
    print("Number of documents found: {}".format(len(docs)))

    #query_hash = process_query(query)

    ranked_tweets,scores = rank_documents(query_terms, docs, index, processed_tweets, tf, idf,flag = flag)
    return ranked_tweets,scores

# %% [markdown]
# ## Queries test for TF-IDF + COSINE SIMILARITY

# %% [markdown]
# Let's try of search method with the query “Support Farmers of India”:

# %% [markdown]
# Note: Second search may last for 1 minute.

# %%
query = "Support Farmers of India"
# first without hashtag similarity weight
flag = False
ranked_tweets,scores = search_tf_idf(query, index, tf, idf, processed_tweets_dict,flag)
top = 20
print(f"Top {top} documents without hashtag similarity:")
print(ranked_tweets[:top])
# Out:
# Number of documents found: 367
# Top 20 documents without hashtag similarity:
# ['doc_23455', 'doc_1922', 'doc_26563', 'doc_22269', 'doc_21005', 'doc_27466', 'doc_7053', 'doc_7052', 'doc_7048', 'doc_7046', 'doc_7043', 'doc_7041', 'doc_7040', 'doc_7038', 'doc_7035', 'doc_7034', 'doc_7031', 'doc_7028', 'doc_7025', 'doc_7021']

# %%
# Now with hashtag similarity weight
flag = True
ranked_tweets,scores = search_tf_idf(query, index, tf, idf, processed_tweets_dict,flag)
print(f"Top {top} documents with hashtag similarity:")
print(ranked_tweets[:top])
# Out:
# Number of documents found: 367
# Top 20 documents with hashtag similarity:
# ['doc_26563', 'doc_21005', 'doc_19136', 'doc_25316', 'doc_23455', 'doc_1922', 'doc_42666', 'doc_967', 'doc_32483', 'doc_17175', 'doc_22625', 'doc_26453', 'doc_22269', 'doc_25609', 'doc_47063', 'doc_5482', 'doc_27466', 'doc_22096', 'doc_27735', 'doc_7053']

# %% [markdown]
# Here are the top 1 tweet WITHOUT hashtag similarity for query = "Support Farmers of India":

# %%
print("Best result for search WITHOUT hashtag similarity:")
original_tweets_dict['doc_23455']
# Out:
# Best result for search WITHOUT hashtag similarity:
# {'tweet': 'Supporting farmers in India! #FarmersProtest https://t.co/o9I0uENPe4',
#  'hashtags': ['#FarmersProtest'],
#  'date': '2021-02-17T14:53:00+00:00',
#  'likes': 1,
#  'retweets': 0,
#  'url': 'https://twitter.com/PreetiPMenon/status/1362052432071708675',
#  'comment_count': 0}

# %% [markdown]
# Here are the top 1 tweet WITH hashtag similarity for query = "Support Farmers of India":

# %%
print("Best result for search WITH hashtag similarity:")
original_tweets_dict['doc_26563']
# Out:
# Best result for search WITH hashtag similarity:
# {'tweet': 'Wake up India Support farmers 🙏😞  #FarmersMakeIndia #FarmersProtest https://t.co/aNybKF9EGs',
#  'hashtags': ['#FarmersMakeIndia', '#FarmersProtest'],
#  'date': '2021-02-17T01:34:06+00:00',
#  'likes': 3,
#  'retweets': 1,
#  'url': 'https://twitter.com/Gursewak1991/status/1361851385742913542',
#  'comment_count': 0}

# %% [markdown]
# # <b>RANKING 2:</b> Our Score + Cosine Similarity

# %% [markdown]
# Implementation for our score as:
#
#
# - <b>Step 1:</b> popularity_score= (γ⋅likes + δ⋅retweets + ϵ⋅comments)*date<br>
# where <b>date</b> is a recency factor
#
# - <b>Step 2:</b> final_score= α⋅tf_idf_score + β⋅hashtag_similarity_score + Ɣ*popularity_score
#
# - <b>Step 3:</b> Bert Similarity between hashtags and query (done in project part 2)

# %% [markdown]
# ## Popularity score function

# %% [markdown]
# First we are creating a function to obtain the most recent tweet date so that it will be useful for the popularity score computation:

# %%
from datetime import datetime, timezone
import math

def get_newest_tweet(tweets):
    """
    Finds the newest tweet based on the date.

    Input:
        tweets: list - list of tweet JSON objects, each with a 'date' field in ISO format.

    Output:
        newest_tweet: dict - the tweet JSON object with the most recent date.
    """
    # Convert dates and find the tweet with the maximum date
    newest_tweet = max(tweets, key=lambda tweet: datetime.fromisoformat(tweet['date'].replace("Z", "+00:00")))
    return newest_tweet

# %%
most_recent = get_newest_tweet(original_tweets_dict.values())['date']
most_recent = datetime.fromisoformat(most_recent.replace("Z", "+00:00"))
print(f"The most recent tweet date is {most_recent}")
# Out:
# The most recent tweet date is 2021-02-24 09:23:35+00:00

# %%
def popularity_score(tweet,recent_date): # compute the popularity score defined above based on the tweet characteristics
    """
    Computes a popularity score based on tweets characteristics

    Input:
        tweet: tweet json object
        recent_date: date of the most recent tweet

    Output:
        Popularity Score (number)
    """
    likes = tweet['likes']
    retweets = tweet['retweets']
    comments = tweet['comment_count']
    date = tweet['date']
    date = datetime.fromisoformat(date.replace("Z", "+00:00"))


    # Calculate recency factor
    days_since_tweet = (recent_date - date).days
    recency_factor = math.exp(-0.05 * days_since_tweet)  # Decay factor based on days

    # Calculate popularity score
    score = (0.5 * likes + 0.5 * retweets + 0.3 * comments) * recency_factor

    return score

# %% [markdown]
# ## Ranking function

# %%
def rank_documents(query, docs, index,processed_tweets,original_tweets_dict, tf, idf, alpha=1, beta=3, flag=False, recent_date=most_recent):
    """
    Ranks documents based on their relevance (in descending order) to the query using TF-IDF scores.

    Input:
        query: The search query as a list of terms (preprocessed)
        docs: A list of document IDs to be ranked.
        index: The inverted index for tweets.
        processed_tweets: processed tweets dictionary
        original_tweets_dict: original tweets dictionary
        tf: term frequency dictionary
        idf: The inverse document frequency dictionary.
        alpha: Weight for the TF-IDF score.
        beta: Weight for the similarity score between hashtags.
        flag: boolean which indicates whether to use or not the hashtag similarity score (additional to the tf-idf)
        recent_date: date of the most recent tweet

    Output:
        A list of document IDs sorted by their relevance to the query and their scores
    """
    doc_vectors = defaultdict(lambda: [0] * len(query))  # Initialize all scores to 0
    query_vector = [0] * len(query)

    query_terms_count = collections.Counter(query)

    query_norm = la.norm(list(query_terms_count.values()))


    for termIndex, term in enumerate(query):
        if term not in index:
        # as the term does not exist, return anything
            return []

        query_vector[termIndex] = query_terms_count[term] / query_norm * idf[term]

        for doc_index, (doc, postings) in enumerate(index[term]):
            if doc in docs:
            #if doc in tf and term in tf[doc] and doc in tfidf and term in tfidf[doc]:
                doc_vectors[doc][termIndex] = tf[term][doc_index] * idf[term]

    # array d'arrays
    scores = [[np.dot(curDocVec, query_vector), doc] for doc, curDocVec in doc_vectors.items() ]

    if flag:
        # compute the similarity between query and hashtags --> we are joining query together as hashtags are one-word terms
        for doc_id in docs:
            # perform combinations of 2 words
            score_tweet = 0
            for i in range(len(query)):
                for j in range(i+1,len(query)):
                    temp = best_score(processed_tweets_dict[doc_id]['hashtags'], query[i]+query[j])
                    score_tweet = max(score_tweet,temp)

            for i in range(len(scores)):
                if scores[i][1] == doc_id:
                    # for the BERT similarity between query terms and hashtags
                    scores[i][0] = (alpha * scores[i][0] + beta * score_tweet)
                    # for the popularity score
                    temp = popularity_score(original_tweets_dict[doc_id],recent_date)
                    scores[i][0] = scores[i][0] + temp

                    break  # Exit the loop once the doc_id is found

    scores.sort(reverse=True)
    ranked_tweets = [x[1] for x in scores]

    # Sort documents by relevance score (descending)
    return ranked_tweets, scores

def search_tf_idf(query, index, tf, idf, processed_tweets,original_tweets_dict,flag,most_recent):
    """
    Searches for documents relevant to the query using TF-IDF scores.

    Input:
        query: The search query as a string.
        index: The inverted index.
        tf: term frequency term - document
        idf: The inverse document frequency dictionary per term
        processed_tweets: processed tweets dictionary
        original_tweets_dict: processed tweets dictionary
        flag: boolean which indicates whether to use or not the hashtag similarity score (additional to the tf-idf)
        most_recent: date of the most recent tweet

    Output:
        A list of document IDs sorted by their relevance to the query.
    """
    query_terms = build_terms(query)[0]  # Preprocess the query

    docs = set(original_tweets_dict.keys())
    for term in query_terms:
        try:
            # store in term_docs the ids of the docs that contain "term"
            term_docs=[posting[0] for posting in index[term]]

            # docs = docs Intersection term_docs --> applying AND method for tweets seach
            docs = docs.intersection(set(term_docs))
        except:
            #term is not in index
            pass
    docs = list(docs)
    print("Number of documents found: {}".format(len(docs)))

    #query_hash = process_query(query)

    ranked_tweets,scores = rank_documents(query_terms, docs, index, processed_tweets,original_tweets_dict, tf, idf,flag = flag,recent_date=most_recent)
    return ranked_tweets,scores

# %% [markdown]
# ## Queries for OUR SCORE method

# %% [markdown]
# This may take 1 minute, depending on the number of results for the given query:

# %%
query = "Support Farmers of India"
flag = True
ranked_tweets,scores = search_tf_idf(query, index, tf, idf, processed_tweets_dict,original_tweets_dict,flag,most_recent)
top = 20
print(f"Top {top} documents with hashtag similarity + popularity score:")
print(ranked_tweets[:top])
# Out:
# Number of documents found: 367
# Top 20 documents with hashtag similarity + popularity score:
# ['doc_37099', 'doc_6462', 'doc_32035', 'doc_19518', 'doc_38015', 'doc_44945', 'doc_28694', 'doc_8439', 'doc_29886', 'doc_28348', 'doc_26453', 'doc_27922', 'doc_34789', 'doc_23250', 'doc_28457', 'doc_37497', 'doc_5169', 'doc_44218', 'doc_8153', 'doc_15303']

# %%
print("The top 1 tweet for the previous query:")
original_tweets_dict['doc_37099']
# Out:
# The top 1 tweet for the previous query:
# {'tweet': 'Disha Ravi is 21 yrs\n\nA climate activist from India she campaigns for clean air, clean water and a liveable planet\n\nShe is now facing state sanctioned violence for peacefully supporting farmers\n\nSilence is not an option we must all condemn this act of suppression\n\n#FarmersProtest',
#  'hashtags': ['#FarmersProtest'],
#  'date': '2021-02-14T14:59:11+00:00',
#  'likes': 2843,
#  'retweets': 1525,
#  'url': 'https://twitter.com/ClaudiaWebbe/status/1360966826298138629',
#  'comment_count': 1065}

# %%
print("The top 2 tweet for the previous query:")
original_tweets_dict['doc_6462']
# Out:
# The top 2 tweet for the previous query:
# {'tweet': "In US, cotton farmers receive a massive subsidy support of Rs 85.10 lakh ($1,17,494) per farmer/year. In India, it is barely Rs 1,455 ($27) [Source:IIFT]. This is how US has 'market competitiveness' in cotton. Our cotton growers are left to commit suicide. #FarmersProtest",
#  'hashtags': ['#FarmersProtest'],
#  'date': '2021-02-22T09:13:28+00:00',
#  'likes': 1590,
#  'retweets': 723,
#  'url': 'https://twitter.com/Devinder_Sharma/status/1363778926670012416',
#  'comment_count': 37}

# %% [markdown]
# As we can see now, the tweets shown are more relevant so that they may contain similar content (as shown in td-idf + cosine similarity), but now top tweets are more relevant.

# %% [markdown]
# # <b>RANKING 3:</b> BM25

# %% [markdown]
# In this section we are implementing BM25 algorithm for the search of tweets for a given query:

# %%
# !pip install rank-bm25
# Out:
# Collecting rank-bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank-bm25) (1.26.4)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank-bm25
# Successfully installed rank-bm25-0.2.2

# %% [markdown]
# ## Algorithm Implementation

# %%
from collections import Counter

# %%
def bm25_score(query, doc, idf, avgdl, k1=1.5, b=0.75):
    """
    Compute the bm25 score for a tweet given a query

    Input:
      query - processed query
      doc - processed tweet content
      idf - inverted document frequency dictionary
      avgdl - average document length
      k1 - tuning parameter
      b - tuning parameter

    Output:
      bm25 score (number)
    """
    # document has to contain ALL QUERY TERMS
    if not all(term in doc for term in query):
        return 0.0  # 0 score for not containing all query terms


    score = 0.0
    doc_len = len(doc)
    doc_freq = Counter(doc)
    for term in query:
        if term in doc_freq:
            f = doc_freq[term]
            score += idf.get(term, 0) * ((f * (k1 + 1)) / (f + k1 * (1 - b + b * (doc_len / avgdl))))
    return score

tweet_ids = list(processed_tweets_dict.keys())
tokenized_tweets = [data['tweet'] for data in processed_tweets_dict.values()]
avgdl = sum(len(doc) for doc in tokenized_tweets) / len(tokenized_tweets)

# %% [markdown]
# ## Ranking for BM25

# %%
original = "Support Farmers of India"
query = build_terms(original)[0]

#BM25 score for each document
results = []
for tweet_id, tweet_content in zip(tweet_ids, tokenized_tweets):
    score = bm25_score(query, tweet_content, idf, avgdl) # idf computed at the beginning of the notebook!
    results.append({'id': tweet_id, 'score': score})

results = sorted(results, key=lambda x: x['score'], reverse=True)
# top results
top = 20
print(results[:top])
# Out:
# [{'id': 'doc_1922', 'score': 8.369238535920596}, {'id': 'doc_23455', 'score': 8.369238535920596}, {'id': 'doc_22269', 'score': 7.895476736112643}, {'id': 'doc_26563', 'score': 7.895476736112643}, {'id': 'doc_27466', 'score': 7.863373058556089}, {'id': 'doc_21005', 'score': 7.666260851366665}, {'id': 'doc_11660', 'score': 7.472478304943371}, {'id': 'doc_15369', 'score': 7.472478304943371}, {'id': 'doc_19136', 'score': 7.472478304943371}, {'id': 'doc_21596', 'score': 7.472478304943371}, {'id': 'doc_22101', 'score': 7.472478304943371}, {'id': 'doc_25316', 'score': 7.472478304943371}, {'id': 'doc_32785', 'score': 7.472478304943371}, {'id': 'doc_42666', 'score': 7.472478304943371}, {'id': 'doc_4323', 'score': 7.4505931147254145}, {'id': 'doc_4325', 'score': 7.4505931147254145}, {'id': 'doc_4333', 'score': 7.4505931147254145}, {'id': 'doc_4334', 'score': 7.4505931147254145}, {'id': 'doc_4336', 'score': 7.4505931147254145}, {'id': 'doc_4337', 'score': 7.4505931147254145}]

# %%
print(f"QUERY = {original}")
# Out:
# QUERY = Support Farmers of India

# %%
print("Top 1 tweet for the previous query:")
original_tweets_dict['doc_1922']
# Out:
# Top 1 tweet for the previous query:
# {'tweet': '#FarmersProtest  I support farmers in india',
#  'hashtags': ['#FarmersProtest'],
#  'date': '2021-02-23T18:31:49+00:00',
#  'likes': 0,
#  'retweets': 0,
#  'url': 'https://twitter.com/nowTekTalk1/status/1364281828283187205',
#  'comment_count': 0}

# %%
print("Top 2 tweet for the previous query:")
original_tweets_dict['doc_23455']
# Out:
# Top 2 tweet for the previous query:
# {'tweet': 'Supporting farmers in India! #FarmersProtest https://t.co/o9I0uENPe4',
#  'hashtags': ['#FarmersProtest'],
#  'date': '2021-02-17T14:53:00+00:00',
#  'likes': 1,
#  'retweets': 0,
#  'url': 'https://twitter.com/PreetiPMenon/status/1362052432071708675',
#  'comment_count': 0}

# %% [markdown]
# As we can see here, the length of the document is normalized so that we have as top results short tweets.

# %% [markdown]
# # **RANKING 4**: Word2vec + cosine similarity

# %% [markdown]
# In this section, we are implementing a ranking model from the embeddings of the tweets generated with the word2vec model from gensim (the library we used in the previous lab for the visualization part). Once we have the vectors, we apply the cosine similarity to retrieve the top-20 relevant tweets.

# %% [markdown]
# ## Implementation

# %%
from gensim.models.word2vec import Word2Vec
from numpy import dot
from numpy.linalg import norm
import numpy as np

# %%
# State the model from our tweet corpus
corpus = [tweet_data['tweet'] for tweet_data in processed_tweets_dict.values()]
model = Word2Vec(corpus, vector_size=100, window=5, min_count=1, workers=4)

# %%
# Helper function to compute the average embedding for a list of words
def average_vector(words, model):

    """
    Compute the average embedding vector for a list of words.

    Parameters:
        words (list of str): List of words for which the average embedding is computed.
        model (gensim.models.KeyedVectors): Trained word embedding model used to retrieve the vector for each word.

    Returns:
        The average embedding vector for the words provided, with the same dimension
            as the model's word vectors. If none of the words are in the model's vocabulary,
            returns a zero vector.
    """

    # Only use words that are in the vocabulary
    vectors = [model.wv[word] for word in words if word in model.wv.key_to_index]
    # Return the mean vector, or a zero vector if no words are in the model vocabulary
    return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

# Function to retrieve the top 20 most similar tweets to a given query
def get_top_20_tweets(query, model, processed_tweets_dict, original_tweets_dict):

    # Tokenize the query (assumes a simple whitespace split; adjust if needed)
    query_words = build_terms(query)

    # Calculate the vector for the query
    query_vector = average_vector(query_words[0], model)

    cosine_similarities = {}

    for tweet_id, tweet_data in processed_tweets_dict.items():
        tweet_words = tweet_data['tweet']

        # Ensure the tweet contains all terms from the query
        if all(term in tweet_words for term in query_words[0]):
            # Convert the tweet words into a vector embedding
            tweet_vector = average_vector(tweet_words, model)

            # Compute cosine similarity between the query and tweet vectors
            if np.any(query_vector) and np.any(tweet_vector):  # Ensure vectors are not all zeros
                cosine_similarity = dot(query_vector, tweet_vector) / (norm(query_vector) * norm(tweet_vector))
                cosine_similarities[tweet_id] = cosine_similarity

    # Sort tweets by similarity and get the top 20
    top_20_tweets = sorted(cosine_similarities, key=cosine_similarities.get, reverse=True)[:20]

    # Collect the results as a list of tuples (tweet_id, similarity, tweet_text)
    results = [(tweet_id, cosine_similarities[tweet_id], original_tweets_dict[tweet_id]) for tweet_id in top_20_tweets]

    return results

# %% [markdown]
# ## Query 1: Are farmers being respected in India?

# %%
query = "Are farmers being respected in India?"
top_20_tweets = get_top_20_tweets(query, model, processed_tweets_dict, original_tweets_dict)

# Print the top 20 tweets
print(f"\nTop 20 most similar tweets for query {query}:")
for tweet_id, similarity, tweet_text in top_20_tweets:
    print(f"\nTweet ID: {tweet_id}, Similarity: {similarity}")
    print(f"Tweet text: {tweet_text}")
# Out:
# Top 20 most similar tweets for query Are farmers being respected in India?:
#
# Tweet ID: doc_43729, Similarity: 0.9656084179878235
# Tweet text: {'tweet': 'In India everything on sale\nBut not our respected Farmers \nSalute to them\n\n#RepealOnlyWayAhead \n#FarmersProtest https://t.co/LmU8NeZmNd', 'hashtags': ['#RepealOnlyWayAhead', '#FarmersProtest'], 'date': '2021-02-13T02:19:59+00:00', 'likes': 9, 'retweets': 13, 'url': 'https://twitter.com/_BrAr93/status/1360413380196982795', 'comment_count': 0}
#
# Tweet ID: doc_26131, Similarity: 0.9315985441207886
# Tweet text: {'tweet': 'Respect farmers #FarmersMakeIndia \ncountless human rights orgs, farmers &amp; activists stand in solidarity with farmers protesting in India \n#FarmersProtest https://t.co/xgUd8rCVMo', 'hashtags': ['#FarmersMakeIndia', '#FarmersProtest'], 'date': '2021-02-17T02:31:18+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/Mkaur_pb/status/1361865779914756097', 'comment_count': 0}
#
# Tweet ID: doc_25499, Similarity: 0.9296895265579224
# Tweet text: {'tweet': 'Farmer is a magician who produces money from the mud.They are merely considered as animals growing food for us.\nWe should respect them &amp; consider their demands seriously.\n\nStand against Facism... Save Farmers..\n\nMake India Great Again!! 🇮🇳 \n#FarmersProtest\n#FarmersMakeIndia https://t.co/XZfk90hD1u', 'hashtags': ['#FarmersProtest', '#FarmersMakeIndia'], 'date': '2021-02-17T04:08:28+00:00', 'likes': 77, 'retweets': 82, 'url': 'https://twitter.com/pankajbajp16/status/1361890230433816578', 'comment_count': 3}
#
# Tweet ID: doc_25614, Similarity: 0.9292991757392883
# Tweet text: {'tweet': 'A lady that can speak for farmers but can’t respect the culture of india. Just look at neck what she is wearing pathetic #india #banrihanna #IndiaWithModi #rihannadidiji #RihannaSoldOut #rihanna #BJP #FarmersProtest #indian #ganapti #culture #Respect https://t.co/5dLs9Oo5Y3', 'hashtags': ['#india', '#banrihanna', '#IndiaWithModi', '#rihannadidiji', '#RihannaSoldOut', '#rihanna', '#BJP', '#FarmersProtest', '#indian', '#ganapti', '#culture', '#Respect'], 'date': '2021-02-17T03:53:45+00:00', 'likes': 0, 'retweets': 1, 'url': 'https://twitter.com/piyushpersonalT/status/1361886525961641984', 'comment_count': 0}
#
# Tweet ID: doc_2746, Similarity: 0.924524188041687
# Tweet text: {'tweet': '@vinayak_jain @narendramodi Also at an age when people want to sit at home in the warmth with their families the farmers of India are asking to be treated with respect. @narendramodi is sitting in his lovely warm house, doing a job he is paid to do. The Indian farmers are the true heroes #FarmersProtest', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-23T12:30:00+00:00', 'likes': 0, 'retweets': 1, 'url': 'https://twitter.com/NikkiC_36/status/1364190772208291841', 'comment_count': 0}
#
# Tweet ID: doc_43080, Similarity: 0.9172940254211426
# Tweet text: {'tweet': 'Hats off to you @meenaharris \nStay strong. Support the truth. Your twitter voice is being heard in India🌹🌹🙏🙏\n#RepealOnlyWayAhead \n#farmersprotest \nRespect to Farmers union leaders who paved way for this revolution. Salute to all who sacrificed their lives for  farmers protest https://t.co/0u8ZmBQ3iT', 'hashtags': ['#RepealOnlyWayAhead', '#farmersprotest'], 'date': '2021-02-13T05:53:00+00:00', 'likes': 2, 'retweets': 1, 'url': 'https://twitter.com/shells_n_petals/status/1360466986338254851', 'comment_count': 0}
#
# Tweet ID: doc_25231, Similarity: 0.9103147983551025
# Tweet text: {'tweet': 'Farmer is a magician who produces money from the mud.They are merely considered as animals growing food for us.\nWe should respect them &amp; consider their demands seriously.\n\nMake India Great Again!! 🇮🇳 \n#FarmersProtest\n#FarmersMakeIndia https://t.co/GfVfBaI23k', 'hashtags': ['#FarmersProtest', '#FarmersMakeIndia'], 'date': '2021-02-17T04:45:00+00:00', 'likes': 1, 'retweets': 2, 'url': 'https://twitter.com/RovinsanK/status/1361899423920390149', 'comment_count': 0}
#
# Tweet ID: doc_47818, Similarity: 0.9090530276298523
# Tweet text: {'tweet': 'We should build memorial for farmers, whoever died in #FarmersProtest, inside parliament premises.\n\nThey should be respected before important functions, as a ceremony.\n\nLike East Indian Companies, India should be liberated from West Indian Companies Looting', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-12T02:52:46+00:00', 'likes': 3, 'retweets': 3, 'url': 'https://twitter.com/AgainstRiotism/status/1360059241663508483', 'comment_count': 0}
#
# Tweet ID: doc_31678, Similarity: 0.9058630466461182
# Tweet text: {'tweet': 'I joined this letter to @POTUS that expresses grave concerns about ongoing legal abuses and violence being committed against the farmers of India, and calls upon India to respect the constitutional rights of protesters. #FarmersProtest https://t.co/gmgLBPQj2K', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-15T19:14:11+00:00', 'likes': 315, 'retweets': 125, 'url': 'https://twitter.com/KumarRaoNYC/status/1361393387325317121', 'comment_count': 18}
#
# Tweet ID: doc_21692, Similarity: 0.9023076295852661
# Tweet text: {'tweet': 'Drivers of Indian Locomotives 🚂 can extend their tacit support to #FARMERSPROTEST by halting the rail traffic for these 4 hours as a mark of respect for the Rights of India’s 40+ crore Farmers... https://t.co/BcMt32juZa', 'hashtags': ['#FARMERSPROTEST'], 'date': '2021-02-18T03:00:33+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/raghav4india/status/1362235528230363138', 'comment_count': 0}
#
# Tweet ID: doc_38170, Similarity: 0.8970857262611389
# Tweet text: {'tweet': 'Indian diaspora groups in US launch rose campaign in support of farmers in India\n\n“Tweet or Send a Rose to Modi asking to repeal farm laws or Send a Rose to the Indian Embassy in your respective region #Rose2Repeal #LoveToFarmers #OneAppealRepeal”\n\n#FarmersProtest #GodiMedia', 'hashtags': ['#Rose2Repeal', '#LoveToFarmers', '#OneAppealRepeal', '#FarmersProtest', '#GodiMedia'], 'date': '2021-02-14T10:33:52+00:00', 'likes': 23, 'retweets': 5, 'url': 'https://twitter.com/HarteerathSingh/status/1360900057243947011', 'comment_count': 0}
#
# Tweet ID: doc_31554, Similarity: 0.8959434032440186
# Tweet text: {'tweet': '👉🏽RT @KumarRaoNYC: I joined this letter to @POTUS that expresses grave concerns about ongoing legal abuses and violence being committed against the farmers of India, and calls upon India to respect the constitutional rights of protesters. #FarmersProtest https://t.co/O1C8gbiZFO', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-15T20:22:58+00:00', 'likes': 3, 'retweets': 1, 'url': 'https://twitter.com/tweetSAMRAT/status/1361410696567803906', 'comment_count': 0}
#
# Tweet ID: doc_12911, Similarity: 0.861616313457489
# Tweet text: {'tweet': "#ShameonBollywood #WakeUpIndia @PMOIndia @ZeeNewsEnglish @AnupamPKher @smritiirani @AmitShah  Stay with Truths Respected Citizens or Minister's of My India ✌️ They are Farmers not Terrorists. #KisaanMajdoorEktaZindabad #FarmersProtest https://t.co/gjD9K6H4M3", 'hashtags': ['#ShameonBollywood', '#WakeUpIndia', '#KisaanMajdoorEktaZindabad', '#FarmersProtest'], 'date': '2021-02-20T09:28:19+00:00', 'likes': 1, 'retweets': 0, 'url': 'https://twitter.com/Itsexceptional1/status/1363057888122478592', 'comment_count': 0}
#
# Tweet ID: doc_26198, Similarity: 0.8560468554496765
# Tweet text: {'tweet': "#FarmersMakeIndia\n\nFarmers feed the India and their son's defends India on the borders. \n\nFight for them. Protect them. Respect them.\n\nwithdraw the 3 black laws &amp; make law on MSP.\n#FarmersProtest \n #FarmerLivesMatter https://t.co/gzeNSOvV99", 'hashtags': ['#FarmersMakeIndia', '#FarmersProtest', '#FarmerLivesMatter'], 'date': '2021-02-17T02:20:24+00:00', 'likes': 2, 'retweets': 3, 'url': 'https://twitter.com/babusinhsolank5/status/1361863037037080576', 'comment_count': 0}
#
# Tweet ID: doc_26210, Similarity: 0.8560468554496765
# Tweet text: {'tweet': "#FarmersMakeIndia\n\nFarmers feed the India and their son's defends India on the borders. \n\nFight for them. Protect them. Respect them.\n\nwithdraw the 3 black laws &amp; make law on MSP.\n#FarmersProtest \n #FarmerLivesMatter https://t.co/dxctZPlHjb", 'hashtags': ['#FarmersMakeIndia', '#FarmersProtest', '#FarmerLivesMatter'], 'date': '2021-02-17T02:17:58+00:00', 'likes': 7, 'retweets': 3, 'url': 'https://twitter.com/HryTweet_/status/1361862423766966273', 'comment_count': 1}
#
# Tweet ID: doc_39021, Similarity: 0.8487287163734436
# Tweet text: {'tweet': "#FarmersProtest #FarmersProtestDelhi2020 Sambit Patraji, Amit Shahji kya aap dono bhi humaare Modiji ki tarah Farmers protest ko parasites kehte ho? To aap dono bhi anti national ho, please respect the food farmers give everyone &amp; 70% of India's GDP, Sedition ?Send these 3 where? https://t.co/iOu7L5abdf", 'hashtags': ['#FarmersProtest', '#FarmersProtestDelhi2020'], 'date': '2021-02-14T05:05:30+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/AVankad/status/1360817421867704320', 'comment_count': 0}
#
# Tweet ID: doc_44952, Similarity: 0.8464610576629639
# Tweet text: {'tweet': '@AmandaCerny @rihanna plz accept the respect from farmers of India to support #FarmersProtest https://t.co/oeNyRLxqNF', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-12T16:58:10+00:00', 'likes': 1, 'retweets': 0, 'url': 'https://twitter.com/kamaljaj/status/1360271993451384832', 'comment_count': 0}
#
# Tweet ID: doc_47565, Similarity: 0.834735631942749
# Tweet text: {'tweet': "@kpopmexico95 @AmandaCerny Good work buddy 👍👍👍👍\nIt will be great If you can show your art or skills in respect of India's farmers. Plz do some favor 🙏🙏\n🚜🌾🚜🌾🚜🌾🚜🌾\n\n#FarmersProtest #StandWithFarmers \n#NoFarmerNoFood #KisanEktaMorcha @Kisanektamorcha", 'hashtags': ['#FarmersProtest', '#StandWithFarmers', '#NoFarmerNoFood', '#KisanEktaMorcha'], 'date': '2021-02-12T03:37:14+00:00', 'likes': 23, 'retweets': 0, 'url': 'https://twitter.com/ParamSingh90/status/1360070433442209792', 'comment_count': 0}

# %% [markdown]
# ## Query 2: Are people supporting Farmers?

# %%
query = "Are people supporting Farmers?"
top_20_tweets = get_top_20_tweets(query, model, processed_tweets_dict, original_tweets_dict)

# Print the top 20 tweets
print(f"\nTop 20 most similar tweets for query {query}:")
for tweet_id, similarity, tweet_text in top_20_tweets:
    print(f"\nTweet ID: {tweet_id}, Similarity: {similarity}")
    print(f"Tweet text: {tweet_text}")
# Out:
# Top 20 most similar tweets for query Are people supporting Farmers?:
#
# Tweet ID: doc_25223, Similarity: 1.0
# Tweet text: {'tweet': 'Support farmers people #FarmersProtest #FarmersMakelndia https://t.co/m6IJvMdHFt', 'hashtags': ['#FarmersProtest', '#FarmersMakelndia'], 'date': '2021-02-17T04:46:26+00:00', 'likes': 2, 'retweets': 1, 'url': 'https://twitter.com/Be1Benipal/status/1361899786807386115', 'comment_count': 0}
#
# Tweet ID: doc_41400, Similarity: 0.9976512789726257
# Tweet text: {'tweet': 'TN PEOPLE SUPPORTING FARMERS #FarmersProtest #StandWithFarmers #FarmersProtest', 'hashtags': ['#FarmersProtest', '#StandWithFarmers', '#FarmersProtest'], 'date': '2021-02-13T16:29:39+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/karthikchella/status/1360627204107894787', 'comment_count': 0}
#
# Tweet ID: doc_31432, Similarity: 0.9752092361450195
# Tweet text: {'tweet': 'This is a farmers protest for farmers by farmers , common people !! Please keep supporting farmers if these people can still support after losing their son #FarmersProtest https://t.co/KYj5qVMAAy', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-15T21:25:17+00:00', 'likes': 9, 'retweets': 3, 'url': 'https://twitter.com/amanmangat08/status/1361426377887477764', 'comment_count': 0}
#
# Tweet ID: doc_46581, Similarity: 0.9690935611724854
# Tweet text: {'tweet': 'Little brave girl support farmer shame on people who still sleeping in house wakeup and support the farmer if you want to save your children future..#FarmersProtest #isupportfarmersprotest #un https://t.co/vBaGNxAJtE', 'hashtags': ['#FarmersProtest', '#isupportfarmersprotest', '#un'], 'date': '2021-02-12T07:12:57+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/RamanMe46067188/status/1360124719853277190', 'comment_count': 0}
#
# Tweet ID: doc_22096, Similarity: 0.9627498984336853
# Tweet text: {'tweet': '#RailRokoForFarmers\nNo farmers no food,\nSupport farmers save nation,\nFarmers are backbone of india,\nPower of people is stronger than people in power,\nFarmers are India. #FarmersMakelndia #FarmersProtest #FarmersProtests #Farmers https://t.co/Jcq3QpNabJ', 'hashtags': ['#RailRokoForFarmers', '#FarmersMakelndia', '#FarmersProtest', '#FarmersProtests', '#Farmers'], 'date': '2021-02-18T01:39:17+00:00', 'likes': 1, 'retweets': 1, 'url': 'https://twitter.com/aesthet71756549/status/1362215076510326786', 'comment_count': 0}
#
# Tweet ID: doc_12189, Similarity: 0.961789608001709
# Tweet text: {'tweet': 'Farmers are People who are willing to stand up to those who are running and supporting broken, unfair, and inhumane systems.Please support #FarmersProtest', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-20T14:28:09+00:00', 'likes': 11, 'retweets': 5, 'url': 'https://twitter.com/amarsran/status/1363133341994729473', 'comment_count': 1}
#
# Tweet ID: doc_43246, Similarity: 0.9580157995223999
# Tweet text: {'tweet': 'Still see people who support farmers still following KanganRot.... 🧐 #FarmersProtests #RepealOnlyWayAhead #farmersprotest', 'hashtags': ['#FarmersProtests', '#RepealOnlyWayAhead', '#farmersprotest'], 'date': '2021-02-13T04:55:21+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/B56Ricky/status/1360452477296865286', 'comment_count': 0}
#
# Tweet ID: doc_3695, Similarity: 0.9564821720123291
# Tweet text: {'tweet': '@ElvishYadav \nI am going to unsubscribe your channel and request to the people of India who are in support of farmers please unsubscribe his channel and boycott the people who are against farmers.\n#FarmersProtest #kissanmazdoorektazindabaad https://t.co/Yi5ugJbYWy', 'hashtags': ['#FarmersProtest', '#kissanmazdoorektazindabaad'], 'date': '2021-02-23T06:14:09+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/Gurpree85529033/status/1364096187096203265', 'comment_count': 0}
#
# Tweet ID: doc_25009, Similarity: 0.9555985927581787
# Tweet text: {'tweet': 'These are the people who want to live with dignity. These are the people whom we need to show solidarity. They are away from their homes. Reforms should be to benefit the farmers not against them. Anyone with a conscious and mind that reasons will support the #FarmersProtest https://t.co/XRAFekSfHL', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-17T05:11:53+00:00', 'likes': 26, 'retweets': 11, 'url': 'https://twitter.com/simasim111/status/1361906189395628032', 'comment_count': 1}
#
# Tweet ID: doc_15516, Similarity: 0.954368531703949
# Tweet text: {'tweet': '@LaSg16515359 @arzt28 @mssirsa We started with request to reappeal three farmer laws as farmers are scared but the way BJP/RSS harassing innocent people whoever is supporting Farmers agitation is very shameful. This is how they care or respect  their citizen? Where is democracy?ShameBJP #FarmersProtest', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-19T20:05:12+00:00', 'likes': 2, 'retweets': 0, 'url': 'https://twitter.com/DaljeetJohal3/status/1362855778449715200', 'comment_count': 0}
#
# Tweet ID: doc_1314, Similarity: 0.9507246613502502
# Tweet text: {'tweet': 'Are the Indian people awake yet? How much more will the farmers or their supporters suffer before rest of the nation wakes up! \n\n#ModiDontSellFarmers\n#FarmersProtest https://t.co/WHYpghktMp', 'hashtags': ['#ModiDontSellFarmers', '#FarmersProtest'], 'date': '2021-02-24T01:45:47+00:00', 'likes': 7, 'retweets': 14, 'url': 'https://twitter.com/NavJammu/status/1364391039969030144', 'comment_count': 0}
#
# Tweet ID: doc_47335, Similarity: 0.9500444531440735
# Tweet text: {'tweet': 'Farmers are not having fun being on the road for months there’s all the people there is younger people there are people that are sick people haven’t seen their families for months please support #FarmersProtest\n#MahapanchayatRevolution https://t.co/FaSngwdSP7', 'hashtags': ['#FarmersProtest', '#MahapanchayatRevolution'], 'date': '2021-02-12T04:25:56+00:00', 'likes': 0, 'retweets': 1, 'url': 'https://twitter.com/Surinde63892833/status/1360082686224703488', 'comment_count': 0}
#
# Tweet ID: doc_47584, Similarity: 0.9500444531440735
# Tweet text: {'tweet': 'Farmers are not having fun being on the road for months there’s all the people there is younger people there are people that are sick people haven’t seen their families for months please support #FarmersProtest\n#MahapanchayatRevolution https://t.co/nxWRoRMdQs', 'hashtags': ['#FarmersProtest', '#MahapanchayatRevolution'], 'date': '2021-02-12T03:33:38+00:00', 'likes': 20, 'retweets': 17, 'url': 'https://twitter.com/RandhawaSukkhi/status/1360069526184861697', 'comment_count': 0}
#
# Tweet ID: doc_47639, Similarity: 0.9500444531440735
# Tweet text: {'tweet': 'Farmers are not having fun being on the road for months there’s all the people there is younger people there are people that are sick people haven’t seen their families for months please support #FarmersProtest\n#MahapanchayatRevolution https://t.co/xDUSO37ufc', 'hashtags': ['#FarmersProtest', '#MahapanchayatRevolution'], 'date': '2021-02-12T03:22:07+00:00', 'likes': 3, 'retweets': 3, 'url': 'https://twitter.com/VidyasagarSinh3/status/1360066626704478211', 'comment_count': 0}
#
# Tweet ID: doc_48389, Similarity: 0.9500444531440735
# Tweet text: {'tweet': 'Farmers are not having fun being on the road for months there’s all the people there is younger people there are people that are sick people haven’t seen their families for months please support #FarmersProtest\n#MahapanchayatRevolution https://t.co/KwoEqRVpBD', 'hashtags': ['#FarmersProtest', '#MahapanchayatRevolution'], 'date': '2021-02-12T01:44:15+00:00', 'likes': 102, 'retweets': 151, 'url': 'https://twitter.com/navu061020/status/1360042000054034434', 'comment_count': 3}
#
# Tweet ID: doc_42992, Similarity: 0.9480693936347961
# Tweet text: {'tweet': '#GoBackModi \nWhy that joker is coming here, that he even know people of tamilnadu is not his valentine?                     Support farmers #farmersprotest https://t.co/mGgSABR3Ys', 'hashtags': ['#GoBackModi', '#farmersprotest'], 'date': '2021-02-13T06:26:07+00:00', 'likes': 15, 'retweets': 13, 'url': 'https://twitter.com/karthiga_873/status/1360475321041002498', 'comment_count': 0}
#
# Tweet ID: doc_15894, Similarity: 0.9464325904846191
# Tweet text: {'tweet': 'No one is taking about these people who are also protesting to support farmers #FarmersProtest #StandWithDishaRavi #DalitLivesMatter #andolanjivi #FarmersAboveReligiousHate #FarmersStandingFirm #IndiaBeingSilenced #KisanEktaMorcha #KisanEktaMarch @abhisar_sharma @ajitanjum https://t.co/JPRj7MhFDp', 'hashtags': ['#FarmersProtest', '#StandWithDishaRavi', '#DalitLivesMatter', '#andolanjivi', '#FarmersAboveReligiousHate', '#FarmersStandingFirm', '#IndiaBeingSilenced', '#KisanEktaMorcha', '#KisanEktaMarch'], 'date': '2021-02-19T17:48:40+00:00', 'likes': 2, 'retweets': 1, 'url': 'https://twitter.com/DivdeepM/status/1362821418954670080', 'comment_count': 1}
#
# Tweet ID: doc_25770, Similarity: 0.94481360912323
# Tweet text: {'tweet': 'Wasn\'t that #bannertowing (by an airplane) in support of the farmers? \n🤗🤗\nAnd it read "Support Indian farmers, #FarmersProtest !! That\'s amazing! \nBig thank u2the ace aviator who did it &amp; people of New Zealand, especially the thoughtful residents of Auckland.\n#FarmersMakeIndia https://t.co/ZdzA4iOt02', 'hashtags': ['#bannertowing', '#FarmersProtest', '#FarmersMakeIndia'], 'date': '2021-02-17T03:30:49+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/Aviator_hardeep/status/1361880756834893827', 'comment_count': 0}
#
# Tweet ID: doc_44492, Similarity: 0.944388747215271
# Tweet text: {'tweet': '@TheeraSingh Wow people like you supporting the farmers reminds us of the kindness that exists in the face of hatred #StandWithFarmers #FarmersProtest', 'hashtags': ['#StandWithFarmers', '#FarmersProtest'], 'date': '2021-02-12T19:26:31+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/PKPaz1/status/1360309328331362307', 'comment_count': 0}
#
# Tweet ID: doc_42362, Similarity: 0.9439740180969238
# Tweet text: {'tweet': '"We are hopeful that #FarmersProtest will end through dialogues. This is the government of farmers and they are our people," says @drsanjeevbalyan while basking in the sun along with his supporters in Meerut earlier today. https://t.co/62wtS40pPo', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-13T09:39:03+00:00', 'likes': 4, 'retweets': 0, 'url': 'https://twitter.com/saurabhsherry/status/1360523873104502784', 'comment_count': 0}

# %% [markdown]
# ## Query 3: Fight of farmers in India

# %%
query = "Fight of farmers in India"
top_20_tweets = get_top_20_tweets(query, model, processed_tweets_dict, original_tweets_dict)

# Print the top 20 tweets
print(f"\nTop 20 most similar tweets for query {query}:")
for tweet_id, similarity, tweet_text in top_20_tweets:
    print(f"\nTweet ID: {tweet_id}, Similarity: {similarity}")
    print(f"Tweet text: {tweet_text}")
# Out:
# Top 20 most similar tweets for query Fight of farmers in India:
#
# Tweet ID: doc_11657, Similarity: 0.9981187582015991
# Tweet text: {'tweet': 'How the Diaspora in Britain Is Fighting for India’s Farmers\n\n#FarmersProtest \nhttps://t.co/2EUnfVl6b1', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-20T18:32:52+00:00', 'likes': 1, 'retweets': 2, 'url': 'https://twitter.com/sikhbeard/status/1363194927761551362', 'comment_count': 0}
#
# Tweet ID: doc_17718, Similarity: 0.9845056533813477
# Tweet text: {'tweet': 'Farmers are fighting for not only their future but also for India\n#FarmersProtest \n#ReleaseDetainedFarmers https://t.co/abfKP8hduX', 'hashtags': ['#FarmersProtest', '#ReleaseDetainedFarmers'], 'date': '2021-02-19T04:00:22+00:00', 'likes': 3, 'retweets': 2, 'url': 'https://twitter.com/Jass_k_G/status/1362612968257695751', 'comment_count': 0}
#
# Tweet ID: doc_26322, Similarity: 0.9730579853057861
# Tweet text: {'tweet': 'Farmer feeds India. Let\'s fight for the "FARMER RIGHTS INDIA"\n\n #FarmersMakeIndia\n#FarmersProtest', 'hashtags': ['#FarmersMakeIndia', '#FarmersProtest'], 'date': '2021-02-17T02:06:47+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/MirShareef/status/1361859609602887683', 'comment_count': 0}
#
# Tweet ID: doc_18244, Similarity: 0.9723674058914185
# Tweet text: {'tweet': 'Hey @AOC would you like to support the peaceful farmers fighting for democracy in India and fighting for their livelihood?\n\n#nodeepkaur #freejagginow #FarmersProtest #standwithfarmers #ReleaseDetainedFarmers', 'hashtags': ['#nodeepkaur', '#freejagginow', '#FarmersProtest', '#standwithfarmers', '#ReleaseDetainedFarmers'], 'date': '2021-02-19T02:05:08+00:00', 'likes': 1, 'retweets': 0, 'url': 'https://twitter.com/Gurpreetd86/status/1362583970345549825', 'comment_count': 0}
#
# Tweet ID: doc_4443, Similarity: 0.9687410593032837
# Tweet text: {'tweet': 'This fight will continue untill we win. No Farmer No Food. Wake Up India.\n\n#FarmersProtest \n#KisanMajdoorEktaZindabaad https://t.co/EoL6zFfkwZ', 'hashtags': ['#FarmersProtest', '#KisanMajdoorEktaZindabaad'], 'date': '2021-02-23T03:00:30+00:00', 'likes': 3, 'retweets': 1, 'url': 'https://twitter.com/winderdhillon/status/1364047456015708162', 'comment_count': 0}
#
# Tweet ID: doc_14, Similarity: 0.961843729019165
# Tweet text: {'tweet': 'Pride of Britain charity hero helping poor India farmers fight government battle https://t.co/YgFBzPIWdZ #FarmersProtest', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-24T09:18:02+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/Dallehal/status/1364504850524995587', 'comment_count': 0}
#
# Tweet ID: doc_22625, Similarity: 0.9510397911071777
# Tweet text: {'tweet': '#FarmersProtest is also a fight to save democracy in India\nThank you farmers 🙏 for  withstanding everything\nIf  farmers  fail , democracy in  India  fails\nSo  please  support farmers  to  save  India #FarmersMakeIndia https://t.co/xLVmwLou9C', 'hashtags': ['#FarmersProtest', '#FarmersMakeIndia'], 'date': '2021-02-17T20:18:46+00:00', 'likes': 2, 'retweets': 2, 'url': 'https://twitter.com/Dimpy10137618/status/1362134416986832897', 'comment_count': 0}
#
# Tweet ID: doc_3405, Similarity: 0.9505544304847717
# Tweet text: {'tweet': 'Farming is in our blood. And this is why farmers in India are protesting. The fight is for our existence. \n\n#Pagdi_Sambhal_Jatta \n#FarmersProtest https://t.co/oXhyjVQp4A', 'hashtags': ['#Pagdi_Sambhal_Jatta', '#FarmersProtest'], 'date': '2021-02-23T08:23:14+00:00', 'likes': 9, 'retweets': 18, 'url': 'https://twitter.com/NavJammu/status/1364128674279170048', 'comment_count': 1}
#
# Tweet ID: doc_7972, Similarity: 0.9479907155036926
# Tweet text: {'tweet': "It's not fun spending your days and nights the way the farmers in India are right now, but theyre fighting the fight of their life. They're ready to even die for this cause.\nBut...\n#ModiIgnoringFarmersDeaths\n#FarmersProtest https://t.co/OXchhrRp1A", 'hashtags': ['#ModiIgnoringFarmersDeaths', '#FarmersProtest'], 'date': '2021-02-22T01:44:39+00:00', 'likes': 2, 'retweets': 0, 'url': 'https://twitter.com/ish_kayy/status/1363665976370356224', 'comment_count': 0}
#
# Tweet ID: doc_19518, Similarity: 0.9471811056137085
# Tweet text: {'tweet': 'Join me in support of the farmers fighting for their lives in India. Learn more about the #FarmersProtest today here: https://t.co/6m8TCNGqDO', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-18T14:12:14+00:00', 'likes': 639, 'retweets': 274, 'url': 'https://twitter.com/TeaLeoni/status/1362404562120945665', 'comment_count': 62}
#
# Tweet ID: doc_22766, Similarity: 0.9465744495391846
# Tweet text: {'tweet': '@SusanSarandon Farmers have united India against the autocratic policies of Indian State. Huge gatherings all over India represent the unity and strength of farmers and their resolve to fight for their  livelihood.✊🏼🌾 #FarmersProtest https://t.co/hCbJVC5oHr', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-17T19:16:31+00:00', 'likes': 25, 'retweets': 11, 'url': 'https://twitter.com/World_W_Farmers/status/1362118751253000193', 'comment_count': 0}
#
# Tweet ID: doc_10285, Similarity: 0.9462576508522034
# Tweet text: {'tweet': '🤔🤔🤔🚜🚜🚜🇮🇳🇮🇳🇮🇳\n\n#MSPLawForAllCrops \n#FarmersProtest \nI love my India. I will always fight to save India, Democracy, promote citizens rights, dignity of farmers, justice for all https://t.co/DjQhsjDjXw', 'hashtags': ['#MSPLawForAllCrops', '#FarmersProtest'], 'date': '2021-02-21T05:47:17+00:00', 'likes': 0, 'retweets': 1, 'url': 'https://twitter.com/shells_n_petals/status/1363364649459191809', 'comment_count': 0}
#
# Tweet ID: doc_46861, Similarity: 0.9437743425369263
# Tweet text: {'tweet': 'The farmers and labourers are fighting for human rights in India. A crucial moment in the countries history. \n\n\u2066@hrw\u2069\n\n#farmersprotest #istandwithfarmers  https://t.co/oi33YzWDBr', 'hashtags': ['#farmersprotest', '#istandwithfarmers'], 'date': '2021-02-12T05:54:36+00:00', 'likes': 2, 'retweets': 4, 'url': 'https://twitter.com/thiaragirl/status/1360105002082029570', 'comment_count': 0}
#
# Tweet ID: doc_29301, Similarity: 0.9427602291107178
# Tweet text: {'tweet': 'People normally get retired and get RRSP at this age but elderly farmers in India are fighting for Livelihood and what they have earned throughout their lives #RememberSirChhotuRamInModiEra #FarmersProtest https://t.co/8juiQerSc8', 'hashtags': ['#RememberSirChhotuRamInModiEra', '#FarmersProtest'], 'date': '2021-02-16T08:40:33+00:00', 'likes': 184, 'retweets': 125, 'url': 'https://twitter.com/jdhillonA/status/1361596317454065667', 'comment_count': 5}
#
# Tweet ID: doc_34924, Similarity: 0.9407376050949097
# Tweet text: {'tweet': 'I heard about China - arresting student activist but in India? Do not fight with your own kids who are visionary - Do not fight with your own Farmers who feed. Fight with those who got India’s land.#DishaRavi #FarmersProtest https://t.co/YBT1aIICCC', 'hashtags': ['#DishaRavi', '#FarmersProtest'], 'date': '2021-02-15T03:17:03+00:00', 'likes': 1, 'retweets': 1, 'url': 'https://twitter.com/gilldvmmoga/status/1361152515606110209', 'comment_count': 0}
#
# Tweet ID: doc_19832, Similarity: 0.9403854608535767
# Tweet text: {'tweet': 'These farmers are 60+ years, fighting against an injustice system, fighting for their rights through winter season to now SUMMER Season, the heat will only make it harder for the elderly to cope out there. Yet the India gov still can’t reverse the bill. #FarmersProtest #kisan https://t.co/oAYsP1CiW1', 'hashtags': ['#FarmersProtest', '#kisan'], 'date': '2021-02-18T12:00:11+00:00', 'likes': 51, 'retweets': 24, 'url': 'https://twitter.com/princessxjass/status/1362371329752719363', 'comment_count': 0}
#
# Tweet ID: doc_27468, Similarity: 0.939563512802124
# Tweet text: {'tweet': 'We stand with farmers in India fighting against police brutality and oppression during the #FarmersProtest. It’s on all of us to educate ourselves on this historic movement. \nhttps://t.co/R4jSk60es2', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-16T19:00:44+00:00', 'likes': 34, 'retweets': 8, 'url': 'https://twitter.com/zellieimani/status/1361752389804556289', 'comment_count': 1}
#
# Tweet ID: doc_25995, Similarity: 0.9380522966384888
# Tweet text: {'tweet': 'This isn’t anti India - farmers want to work their fields in India! They love the country, they are fighting against the manner in which these bills were imposed. Amplifying their voices globally is important! #FarmersMakeIndia #FarmersProtest https://t.co/4aINplymn0', 'hashtags': ['#FarmersMakeIndia', '#FarmersProtest'], 'date': '2021-02-17T02:47:41+00:00', 'likes': 1, 'retweets': 0, 'url': 'https://twitter.com/jot__b/status/1361869903402303489', 'comment_count': 0}
#
# Tweet ID: doc_6443, Similarity: 0.9380456805229187
# Tweet text: {'tweet': 'For those who says that this peasant movement belongs only to Punjabi’s \nBut the whole world says it belongs to every farmer in India and they are fighting for their livelihood.👇\n\n#FarmersProtest \n#ModiIgnoringFarmersDeaths @sandhu94717 @Man_shergill @mnprtsandhu34 @kaur_sawera https://t.co/ffokadBC2M', 'hashtags': ['#FarmersProtest', '#ModiIgnoringFarmersDeaths'], 'date': '2021-02-22T09:22:32+00:00', 'likes': 34, 'retweets': 36, 'url': 'https://twitter.com/Jass_8103/status/1363781209436823552', 'comment_count': 6}
#
# Tweet ID: doc_10318, Similarity: 0.937667191028595
# Tweet text: {'tweet': 'Nation, its citizens rights, humanity above all else\n#MSPLawForAllCrops \n#FarmersProtest \nFor the love of India 🇮🇳 Please speak up and support the farmers\nFight to save Democracy, Harmony, unity,promote citizens rights, dignity of farmers, jobs, income and justice for all https://t.co/PrgCfuv23x', 'hashtags': ['#MSPLawForAllCrops', '#FarmersProtest'], 'date': '2021-02-21T05:37:17+00:00', 'likes': 5, 'retweets': 4, 'url': 'https://twitter.com/shells_n_petals/status/1363362135733108736', 'comment_count': 0}

# %% [markdown]
# ## Query 4: Impact of the Protests in India

# %%
query = "Impact of the Protests in India"
top_20_tweets = get_top_20_tweets(query, model, processed_tweets_dict, original_tweets_dict)

# Print the top 20 tweets
print(f"\nTop 20 most similar tweets for query {query}:")
for tweet_id, similarity, tweet_text in top_20_tweets:
    print(f"\nTweet ID: {tweet_id}, Similarity: {similarity}")
    print(f"Tweet text: {tweet_text}")
# Out:
# Top 20 most similar tweets for query Impact of the Protests in India:
#
# Tweet ID: doc_45973, Similarity: 0.9275013208389282
# Tweet text: {'tweet': "The farmers' protest in India is impacting Bollywood with likely after-effects - find out more:\n\nhttps://t.co/YQB7fWVkWQ\n\n#bollywood #FarmersProtest #farmersrprotest #Indian #IndiaTogether", 'hashtags': ['#bollywood', '#FarmersProtest', '#farmersrprotest', '#Indian', '#IndiaTogether'], 'date': '2021-02-12T11:05:02+00:00', 'likes': 1, 'retweets': 0, 'url': 'https://twitter.com/DESIblitz/status/1360183124404166656', 'comment_count': 0}
#
# Tweet ID: doc_23037, Similarity: 0.923944354057312
# Tweet text: {'tweet': "Why are farmers protesting in India, how is the Indian government responding, and what is the impact of the #FarmersProtest around the world? Listen via @thecarolinadesi's latest podcast episode --&gt; https://t.co/bkjuCleFMX. Take action --&gt; https://t.co/wQt69t7gOe https://t.co/kGe8IjfRWU", 'hashtags': ['#FarmersProtest'], 'date': '2021-02-17T17:20:51+00:00', 'likes': 49, 'retweets': 17, 'url': 'https://twitter.com/sikh_coalition/status/1362089639662739462', 'comment_count': 2}
#
# Tweet ID: doc_6542, Similarity: 0.9198969602584839
# Tweet text: {'tweet': 'For anyone who is wondering why farmers are protesting in Delhi, this well-reported story by @parthpunter describes the devastating impact of similar farming reforms elsewhere in India #FarmersProtest https://t.co/zsTrrADGLq', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-22T08:33:38+00:00', 'likes': 248, 'retweets': 84, 'url': 'https://twitter.com/akannampilly/status/1363768903055237125', 'comment_count': 4}
#
# Tweet ID: doc_43591, Similarity: 0.9150411486625671
# Tweet text: {'tweet': "The impact of the farmers' protest in India is likely to effect Bollywood in many ways. We explore why:\n\nhttps://t.co/58y30ut7Ul\n\n#bollywood #FarmersProtest #farmersrprotest #Indian\n#film #businessgrowth", 'hashtags': ['#bollywood', '#FarmersProtest', '#farmersrprotest', '#Indian', '#film', '#businessgrowth'], 'date': '2021-02-13T02:59:00+00:00', 'likes': 2, 'retweets': 1, 'url': 'https://twitter.com/DESIblitz/status/1360423196898570241', 'comment_count': 0}
#
# Tweet ID: doc_41872, Similarity: 0.9121208786964417
# Tweet text: {'tweet': "The farmers' protest in India is impacting Bollywood with likely after-effects - find out more:\n\nhttps://t.co/58y30ut7Ul\n\n@GippyGrewal #bollywood #FarmersProtest #farmersrprotest #Indian", 'hashtags': ['#bollywood', '#FarmersProtest', '#farmersrprotest', '#Indian'], 'date': '2021-02-13T13:20:47+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/DESIblitz/status/1360579675240738819', 'comment_count': 0}
#
# Tweet ID: doc_7237, Similarity: 0.9071394205093384
# Tweet text: {'tweet': '@CNN\n@GLOBALNEWS \n@nytimes \n@CBCNews \n@BBCNews \n250 Indian farmers died in protests\nDeliberate attempt by Government to ignore farmers rights, &amp; devastating impact of these laws  on livelihoods of millions in India. \n#ModiIgnoringFarmersDeaths \n#RepealFarmLaws \n#FarmersProtest https://t.co/PGEw9p9W7R', 'hashtags': ['#ModiIgnoringFarmersDeaths', '#RepealFarmLaws', '#FarmersProtest'], 'date': '2021-02-22T04:07:55+00:00', 'likes': 2, 'retweets': 1, 'url': 'https://twitter.com/shells_n_petals/status/1363702031287013376', 'comment_count': 0}
#
# Tweet ID: doc_5332, Similarity: 0.9063313603401184
# Tweet text: {'tweet': 'For anyone who is Wondering why Farmers are Protesting in Delhi, this Well Reported Story by @parthpunter describes the devastating impact of Similar Farming Reforms elsewhere in India\n\n#FarmersProtest\n\nhttps://t.co/4Es0Lornyy', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-22T20:38:16+00:00', 'likes': 3, 'retweets': 3, 'url': 'https://twitter.com/veenu_sehgal/status/1363951260211179520', 'comment_count': 1}
#
# Tweet ID: doc_45269, Similarity: 0.8991888165473938
# Tweet text: {'tweet': "The farmers' protest in India is impacting Bollywood with likely after-effects - find out more:\n\nhttps://t.co/58y30ut7Ul\n\n@diljitdosanjh #bollywood #FarmersProtest #farmersrprotest #Indian", 'hashtags': ['#bollywood', '#FarmersProtest', '#farmersrprotest', '#Indian'], 'date': '2021-02-12T15:25:54+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/DESIblitz/status/1360248774795345929', 'comment_count': 0}
#
# Tweet ID: doc_45442, Similarity: 0.8990857005119324
# Tweet text: {'tweet': '@Femi_Sorry The farmers protest is also suffering and these goons have showed zero support. India has violated international human rights laws openly and Boris and Priti have turned a blind eye. Even with @amnesty speaking up, it has no impact on this UK government. #farmersprotest #BLM https://t.co/Cj94xHZJnP', 'hashtags': ['#farmersprotest', '#BLM'], 'date': '2021-02-12T14:12:49+00:00', 'likes': 2, 'retweets': 1, 'url': 'https://twitter.com/visastatehouse/status/1360230381165957123', 'comment_count': 0}
#
# Tweet ID: doc_31660, Similarity: 0.8970046043395996
# Tweet text: {'tweet': 'The Premier’s letter to the PM to convey the deep concern that thousands of British Columbians have for the farmers in protest in India.  Thinking of those families impacted by this &amp; worried for their loved ones. #farmersprotest https://t.co/UXaS6v3BvP', 'hashtags': ['#farmersprotest'], 'date': '2021-02-15T19:25:04+00:00', 'likes': 40, 'retweets': 6, 'url': 'https://twitter.com/NikiSharma2/status/1361396126327345156', 'comment_count': 0}
#
# Tweet ID: doc_37212, Similarity: 0.8883869051933289
# Tweet text: {'tweet': '@suelidey @TheMohil8 @BDUTT @DelhiPolice Physical action means to protest. Peaceful protest is a constitutional right in any democracy including India. What is your problem with her? Do you know that? So used to blind hatred that you don’t even question it. \nShe shared a link to help #FarmersProtest have better impact!', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-14T14:31:39+00:00', 'likes': 2, 'retweets': 0, 'url': 'https://twitter.com/SamajhdarIndia/status/1360959896850731011', 'comment_count': 2}
#
# Tweet ID: doc_41864, Similarity: 0.8798471093177795
# Tweet text: {'tweet': '@saahilmenghani this is being done to distract and divert attention from the impact of farmers protests and to drag India back into hindu v/s muslim, since WB elections are around the corner.\n\n#FarmersProtest   #RepealOnlyWayAhead', 'hashtags': ['#FarmersProtest', '#RepealOnlyWayAhead'], 'date': '2021-02-13T13:25:01+00:00', 'likes': 1, 'retweets': 0, 'url': 'https://twitter.com/KattanOru/status/1360580739440414721', 'comment_count': 0}
#
# Tweet ID: doc_40121, Similarity: 0.875528872013092
# Tweet text: {'tweet': '@jimmykimmel @jimmykimmel please raise your voice against the injustices happening in India in the largest peaceful protest! Please support our farmers! This will impact the entire world ! 🥺 #FarmersProtest', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-13T21:55:08+00:00', 'likes': 3, 'retweets': 2, 'url': 'https://twitter.com/ik_stip_boeren/status/1360709114897268742', 'comment_count': 0}

# %% [markdown]
# ## Query 5: Protest against Indian Government

# %%
query = "Protest against Indian Government"
top_20_tweets = get_top_20_tweets(query, model, processed_tweets_dict, original_tweets_dict)

# Print the top 20 tweets
print(f"\nTop 20 most similar tweets for query {query}:")
for tweet_id, similarity, tweet_text in top_20_tweets:
    print(f"\nTweet ID: {tweet_id}, Similarity: {similarity}")
    print(f"Tweet text: {tweet_text}")
# Out:
# Top 20 most similar tweets for query Protest against Indian Government:
#
# Tweet ID: doc_30422, Similarity: 0.9772749543190002
# Tweet text: {'tweet': 'Why are Indian farmers protesting against the government?\n#FarmersProtest  https://t.co/eMUGoXtabZ', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-16T03:39:08+00:00', 'likes': 1, 'retweets': 1, 'url': 'https://twitter.com/manjitghuman58/status/1361520461381738496', 'comment_count': 0}
#
# Tweet ID: doc_17324, Similarity: 0.9623017311096191
# Tweet text: {'tweet': 'The Indian Government immediately stop its escalating crackdown on protesters!! #FarmersProtest #ReleaseDetainedFarmers https://t.co/rnv7Lr7z0P', 'hashtags': ['#FarmersProtest', '#ReleaseDetainedFarmers'], 'date': '2021-02-19T06:34:04+00:00', 'likes': 3, 'retweets': 2, 'url': 'https://twitter.com/reet_kaurz/status/1362651648234029056', 'comment_count': 0}
#
# Tweet ID: doc_18061, Similarity: 0.9623017311096191
# Tweet text: {'tweet': 'The Indian Government immediately stop its escalating crackdown on protesters!! #FarmersProtest #ReleaseDetainedFarmers https://t.co/UciVifa8Wv', 'hashtags': ['#FarmersProtest', '#ReleaseDetainedFarmers'], 'date': '2021-02-19T02:37:32+00:00', 'likes': 97, 'retweets': 121, 'url': 'https://twitter.com/navu061020/status/1362592124277989382', 'comment_count': 4}
#
# Tweet ID: doc_9394, Similarity: 0.9565181732177734
# Tweet text: {'tweet': 'Why are Indian farmers angry ???\nThis is the biggest protest ever against the government.\n🤔🤔🤔🤔🤭🤭🤭🤭\nModi is now German Adolf Hitler.\n\n#FarmersProtests #FarmersProtest\n#India\n#modi_rojgar_do #modi_rojgaar_do https://t.co/gHFFHiLIhm', 'hashtags': ['#FarmersProtests', '#FarmersProtest', '#India', '#modi_rojgar_do', '#modi_rojgaar_do'], 'date': '2021-02-21T14:02:00+00:00', 'likes': 1, 'retweets': 2, 'url': 'https://twitter.com/munawwar581/status/1363489149286834177', 'comment_count': 0}
#
# Tweet ID: doc_45811, Similarity: 0.9506416320800781
# Tweet text: {'tweet': '“The full force and authoritarian tactics of the Indian government have been showcased as they respond to the largest protest in their history.”\n\n#MahapanchayatRevolution\n#FarmersProtest https://t.co/QipOhzUaQE', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T12:10:27+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/1313Kiran/status/1360199588989333505', 'comment_count': 0}
#
# Tweet ID: doc_14153, Similarity: 0.9489180445671082
# Tweet text: {'tweet': '@TeaLeoni Thank you 🙏. The indian government is doing everything illegally to stop this protest. The protesters are in desperate need of water which is not allowed in by police and military. Protesters are dehydrated. #FarmersProtest https://t.co/OucOafTQI6', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-20T03:48:02+00:00', 'likes': 7, 'retweets': 0, 'url': 'https://twitter.com/tinker_sks/status/1362972253076426762', 'comment_count': 0}
#
# Tweet ID: doc_21486, Similarity: 0.9457720518112183
# Tweet text: {'tweet': 'Indian Farmers Protest\n\nThe scenes from the Indian #FarmersProtest have been horrific. So far, there has been a disgraceful lack of #solidarity from the British government and the wider international community\n\n#Railrokoforfarmers https://t.co/4EUFrdH9LD', 'hashtags': ['#FarmersProtest', '#solidarity', '#Railrokoforfarmers'], 'date': '2021-02-18T03:53:44+00:00', 'likes': 18, 'retweets': 6, 'url': 'https://twitter.com/BeantSinghToor3/status/1362248910819926020', 'comment_count': 1}
#
# Tweet ID: doc_40373, Similarity: 0.9454675912857056
# Tweet text: {'tweet': 'This is how Modi thanks his peacefully protesting Indian War Veterans #GoBackModi ! India is governed by a crowd of corrupt incompetents #FarmersProtest https://t.co/E5AD8heuOF', 'hashtags': ['#GoBackModi', '#FarmersProtest'], 'date': '2021-02-13T20:15:22+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/MSpaceRaRa/status/1360684009118916609', 'comment_count': 0}
#
# Tweet ID: doc_47837, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/Gj26p5K2rn', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:47:18+00:00', 'likes': 0, 'retweets': 1, 'url': 'https://twitter.com/JassyParmar/status/1360057864774168576', 'comment_count': 0}
#
# Tweet ID: doc_47839, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/7tHtFG3f6c', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:46:58+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/JassyParmar/status/1360057781412315140', 'comment_count': 0}
#
# Tweet ID: doc_47841, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/188vZX3uyb', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:46:40+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/JassyParmar/status/1360057705080193029', 'comment_count': 0}
#
# Tweet ID: doc_47843, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/vsp05hafFv', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:46:23+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/JassyParmar/status/1360057636759236608', 'comment_count': 0}
#
# Tweet ID: doc_47845, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/w93wR0ovBC', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:46:06+00:00', 'likes': 0, 'retweets': 1, 'url': 'https://twitter.com/JassyParmar/status/1360057561651814403', 'comment_count': 0}
#
# Tweet ID: doc_47848, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/JD4YR7yLX2', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:45:23+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/JassyParmar/status/1360057385008660482', 'comment_count': 0}
#
# Tweet ID: doc_48027, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/2boAEYvTqB', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:21:21+00:00', 'likes': 0, 'retweets': 1, 'url': 'https://twitter.com/JassyParmar/status/1360051337128513539', 'comment_count': 0}
#
# Tweet ID: doc_48059, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/V2yHf7Ze4J', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:18:57+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/JassyParmar/status/1360050733236781056', 'comment_count': 0}
#
# Tweet ID: doc_48070, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/cwI6TkwAyZ', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:17:41+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/JassyParmar/status/1360050414436184064', 'comment_count': 0}
#
# Tweet ID: doc_48074, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/Z3JrHfbKDP', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:17:26+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/JassyParmar/status/1360050348099010562', 'comment_count': 0}
#
# Tweet ID: doc_48079, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/qb7K07I7EQ', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:17:05+00:00', 'likes': 1, 'retweets': 0, 'url': 'https://twitter.com/JassyParmar/status/1360050263382491144', 'comment_count': 0}
#
# Tweet ID: doc_48084, Similarity: 0.9449394941329956
# Tweet text: {'tweet': 'Indian government is trying to silence the voices. The Indian government must immediately stop its escalating crackdown on protesters, farming leaders and journalists, amid ongoing nationwide protest #MahapanchayatRevolution \n#FarmersProtest https://t.co/rTnDHiDbn8', 'hashtags': ['#MahapanchayatRevolution', '#FarmersProtest'], 'date': '2021-02-12T02:16:44+00:00', 'likes': 1, 'retweets': 0, 'url': 'https://twitter.com/JassyParmar/status/1360050172277964810', 'comment_count': 0}

# %% [markdown]
# # Other word embedding tests

# %%
import numpy as np
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument
#from sentence_transformers import SentenceTransformer  # for SBERT
#import tensorflow_hub as hub
from scipy import linalg
from sklearn.metrics.pairwise import cosine_similarity

# Load or initialize each model

# Create the Doc2vec model
corpus = [TaggedDocument(words=tweet_data['tweet'], tags=[str(i)])
          for i, tweet_data in enumerate(processed_tweets_dict.values())] # Create corpus of TaggedDocument objects, each with a unique ID

model = Doc2Vec(corpus, vector_size=100, window=5, min_count=1, workers=4) # Initialize and train the Doc2Vec model

# %%
# Helper function to compute cosine similarity
def compute_similarity(vec1, vec2):
    return np.dot(vec1, vec2) / (linalg.norm(vec1) * linalg.norm(vec2))

# Testing function for USE, Doc2Vec, and SBERT
def test_similarity_models(query, processed_tweets_dict, original_tweets_dict):
    # Convert query to embeddings
    query_doc2vec_vector = model.infer_vector(query.split())

    # Initialize similarity dictionaries
    similarities_doc2vec = {}

    # Loop through tweets and calculate similarity for each model
    for tweet_id, tweet_data in processed_tweets_dict.items():
        tweet_words = tweet_data['tweet']
        tweet_text = " ".join(tweet_words)  # Convert list of words to a single string for USE/SBERT

        # Doc2Vec similarity
        tweet_doc2vec_vector = model.infer_vector(tweet_words)
        similarities_doc2vec[tweet_id] = compute_similarity(query_doc2vec_vector, tweet_doc2vec_vector)

    # Get top 5 similar tweets for each model
    top_5_doc2vec = sorted(similarities_doc2vec, key=similarities_doc2vec.get, reverse=True)[:5]

    # Print results

    print("\nTop 5 tweets using Doc2Vec:")
    for tweet_id in top_5_doc2vec:
        print(f"Tweet ID: {tweet_id}, Similarity: {similarities_doc2vec[tweet_id]}")
        print(f"Tweet Text: {original_tweets_dict[tweet_id]}")

# Example usage
query = "Support Farmers of India"
test_similarity_models(query, processed_tweets_dict, original_tweets_dict)
# Out:
# Top 5 tweets using Doc2Vec:
# Tweet ID: doc_6635, Similarity: 0.3356837091736434
# Tweet Text: {'tweet': 'These are same you beg every #election for votes. Are they humans?\n#FarmersProtest \n#ModiIgnoringFarmersDeaths https://t.co/W3PD088GQF', 'hashtags': ['#election', '#FarmersProtest', '#ModiIgnoringFarmersDeaths'], 'date': '2021-02-22T07:47:11+00:00', 'likes': 0, 'retweets': 0, 'url': 'https://twitter.com/juspreetsra/status/1363757212389179392', 'comment_count': 0}
# Tweet ID: doc_23115, Similarity: 0.3065656721115552
# Tweet Text: {'tweet': 'Every one wants repeal of 3 Farm Acts and legal guarantee of MSP. #FarmersProtest #Revoke3FarmActs #FarmersMakeIndia @hrw @cnn @UNHumanRights @BBCWorld @AlJazeera_World @JoeBiden @TimUppal @amnesty @TanDhesi @JustinTrudeau @BorisJohnson @jacindaardern @Australia @nytimesworld https://t.co/sTnPzgrV3l', 'hashtags': ['#FarmersProtest', '#Revoke3FarmActs', '#FarmersMakeIndia'], 'date': '2021-02-17T16:51:48+00:00', 'likes': 2, 'retweets': 0, 'url': 'https://twitter.com/_gurviir/status/1362082331792605189', 'comment_count': 0}
# Tweet ID: doc_19607, Similarity: 0.30293779207647975
# Tweet Text: {'tweet': '#FarmersProtest  good job every one. 🙏🏼🙏🏼. So proud of you all. So united and peaceful all over in India. https://t.co/gDqjJaj4sI', 'hashtags': ['#FarmersProtest'], 'date': '2021-02-18T13:32:58+00:00', 'likes': 1, 'retweets': 1, 'url': 'https://twitter.com/Gurwind33930102/status/1362394681066201095', 'comment_count': 0}
# Tweet ID: doc_39173, Similarity: 0.29856541712956836
# Tweet Text: {'tweet': 'A retired soldier serving at #FarmersProtest Delhi in his 80s been picked by Indian Government and brutally tortured . He bleeded for serving the nation and the farmers. This is India now #शहीद_जवान_शहीद_किसान https://t.co/z6CuBKCRwo https://t.co/PEOvwukxyH', 'hashtags': ['#FarmersProtest', '#शह'], 'date': '2021-02-14T04:15:08+00:00', 'likes': 2, 'retweets': 0, 'url': 'https://twitter.com/zilch0731/status/1360804744529207297', 'comment_count': 0}
# Tweet ID: doc_1976, Similarity: 0.29255341365425125
# Tweet Text: {'tweet': '👏👏👏👏👏👏. government separates us and humanity brings us together. #FarmersProtest #FarmersProstests #FarmersProtests #KisanAndolan #india #corruption #BJPdestroysDemocracy #supportfarmers #HumanRightsViolations #delhi https://t.co/qfHbmMIN8h', 'hashtags': ['#FarmersProtest', '#FarmersProstests', '#FarmersProtests', '#KisanAndolan', '#india', '#corruption', '#BJPdestroysDemocracy', '#supportfarmers', '#HumanRightsViolations', '#delhi'], 'date': '2021-02-23T18:05:23+00:00', 'likes': 2, 'retweets': 2, 'url': 'https://twitter.com/Goldens75074122/status/1364275175043321860', 'comment_count': 0}
